# %% [markdown]
# ## Deep Neural Networks (DNNs) with PyTorch
#
# - Datasets in the lesson are available through: [https://www.kaggle.com/datasets/yhzang32/2025-course-dl4pde](https://www.kaggle.com/datasets/yhzang32/2025-course-dl4pde)

# %% [markdown]
# ## (1) Creating a Neural Network with PyTorch
#
# In PyTorch, neural networks are constructed using the ```torch.nn module```. A neural network is typically implemented as a class that inherits from ```nn.Module```. Within the class, we define:
# - The architecture (layers) in ```__init__()```.
# - The forward propagation logic in ```forward()```.
#
# ### (1.1) Defining a simple Fully Connected (Feedforward) Neural Network
#
# **Key Notes:**
# - ```nn.Linear(in_features, out_features)``` defines fully connected layers.
# - ```F.relu()``` applies the ReLU activation function.
# - The forward pass defines how data moves through the network.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# Define a simple neural network with 2 hidden layers
class SimpleNN(nn.Module):
    
    def __init__(self, input_size, hidden_size, output_size):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size, bias=True)  # First hidden layer
        self.fc2 = nn.Linear(hidden_size, hidden_size) # Second hidden layer
        self.fc3 = nn.Linear(hidden_size, output_size) # Output layer

    def forward(self, x):
        x = F.relu(self.fc1(x))  # Activation function for hidden layers
        x = F.relu(self.fc2(x))
        x = self.fc3(x)  # Output layer (no activation if regression)
        return x

# Create model instance
model = SimpleNN(input_size=10, hidden_size=20, output_size=1)
print(model)  # Prints the architecture
# Out:
# SimpleNN(
#   (fc1): Linear(in_features=10, out_features=20, bias=True)
#   (fc2): Linear(in_features=20, out_features=20, bias=True)
#   (fc3): Linear(in_features=20, out_features=1, bias=True)
# )

# %% [markdown]
# ### (1.2) Defining DNN models with ```nn.Sequential()```

# %%
import torch
from torch import nn

class SelfNN(nn.Module):

    def __init__(self, arch:list, activation=nn.ReLU()):
        super(SelfNN, self).__init__()
        ##
        self.nn_model = nn.Sequential()
        input_size = arch[0]
        #
        for hidden_size in arch[1:-1]:
            self.nn_model.append(nn.Linear(input_size, hidden_size))
            self.nn_model.append(activation)
            input_size = hidden_size
        #
        self.nn_model.append(nn.Linear(hidden_size, arch[-1]))

    def forward(self, x):
        '''
        Input:
            x: size(batch_size, x_size)
        Output:
            y: size(batch_size, out_size)
        '''
        y = self.nn_model(x)
        
        return y
#
model = SelfNN(arch=[1, 40, 40, 40, 40, 1], activation=nn.ReLU())
print(model)
# Out:
# SelfNN(
#   (nn_model): Sequential(
#     (0): Linear(in_features=1, out_features=40, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=40, out_features=40, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=40, out_features=40, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=40, out_features=40, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=40, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ## (2) Initializing Model Parameters
#
# Proper initialization of weights and biases is crucial for stable training. PyTorch initializes parameters automatically, but we can customize initialization.

# %% [markdown]
# #### Custom Weight Initialization

# %%
import torch.nn.init as init

def initialize_weights(m):
    if isinstance(m, nn.Linear):
        init.xavier_uniform_(m.weight)  # Xavier initialization
        init.zeros_(m.bias)  # Set biases to zero

# Apply initialization to model
model.apply(initialize_weights)
# Out:
# SelfNN(
#   (nn_model): Sequential(
#     (0): Linear(in_features=1, out_features=40, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=40, out_features=40, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=40, out_features=40, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=40, out_features=40, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=40, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# #### Other Initialization Methods
# - ```init.kaiming_uniform_()``` for ReLU-based networks.
# - ```init.normal_()``` for normal distribution initialization.
# **Notes:**
#   - Proper weight initialization prevents vanishing/exploding gradients.
#   - The default initialization algorithm used in PyTorch uses a **Uniform Distribution** with the range depending on the size of the layer, with a formula that looks pretty similar to **Xavier initialization**.

# %% [markdown]
# ## (3) Defining the Loss Function
# The choice of loss function depends on the task:
# - **Regression**: ```nn.MSELoss()``` (Mean Squared Error).
# - **Binary Classification**: ```nn.BCELoss()``` (Binary Cross-Entropy).
# - **Multi-Class Classification**: ```nn.CrossEntropyLoss()```.
#
# #### Defining a Loss Function

# %%
import torch
import torch.nn as nn

criterion = nn.MSELoss()  # Suitable for regression problems
#
x = torch.rand((100,2))
x_ = torch.rand((100,2))
# print('x', x, 'x_', x_)
#
loss = criterion(x, x_)
print('loss:', loss)
# Out:
# loss: tensor(0.1633)

# %%
torch.mean((x-x_)**2)
# Out:
# tensor(0.1633)

# %% [markdown]
# ## (4) Setting Up Optimizers and Training Parameters
# PyTorch provides various optimization algorithms in ```torch.optim```, including:
# - ```optim.SGD(model.parameters(), lr=0.01)``` – Stochastic Gradient Descent.
# - ```optim.Adam(model.parameters(), lr=0.001)``` – Adam optimizer (adaptive learning rate).
# - ```optim.RMSprop(model.parameters(), lr=0.01)``` – Root Mean Square Propagation.
#
# #### Choosing an Optimizer

# %%
import torch.optim as optim

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# **Note:** The learning rate (lr) is a key hyperparameter affecting convergence.

# %% [markdown]
# ## (5) Training a DNN Model
# The training loop involves:
# - **Forward pass**: Compute predictions.
# - **Compute loss**.
# - **Backward pass**: Compute gradients via ```loss.backward()```.
# - **Update weights** using ```optimizer.step()```.
# - **Repeat** for multiple epochs.

# %%
import h5py
import numpy as np
import torch
import matplotlib.pyplot as plt 
#
with h5py.File('regression_1d.h5', 'r') as f:
    print('The dataset regression_1d:', f.keys())
    x_test = torch.tensor(np.array(f['x_test']))
    y_test = torch.tensor(np.array(f['y_test']))
    x_train = torch.tensor(np.array(f['x_train']))
    y_train = torch.tensor(np.array(f['y_train']))
#
plt.figure(figsize=(6, 5))
plt.scatter(x_train, y_train, label='training data')
plt.plot(x_test, y_test, color='r', label='testing data')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='upper left')
plt.show()

# %%
from torch import nn
import torch.optim as optim
import torch.nn.init as init
#
torch.manual_seed(1234)

class SelfNN(nn.Module):

    def __init__(self, arch:list, activation=nn.ReLU()):
        super(SelfNN, self).__init__()
        ##
        self.nn_model = nn.Sequential()
        input_size = arch[0]
        #
        for hidden_size in arch[1:-1]:
            self.nn_model.append(nn.Linear(input_size, hidden_size))
            self.nn_model.append(activation)
            input_size = hidden_size
        #
        self.nn_model.append(nn.Linear(hidden_size, arch[-1]))

    def forward(self, x):
        '''
        Input:
            x: size(batch_size, x_size)
        Output:
            y: size(batch_size, out_size)
        '''
        y = self.nn_model(x)
        
        return y

# Define model
model = SelfNN(arch=[1, 40, 40, 40, 40, 1], activation=nn.ReLU()).to("cpu")

# Apply initialization to model
def initialize_weights(m):
    if isinstance(m, nn.Linear):
        init.xavier_uniform_(m.weight)  # Xavier initialization
        init.zeros_(m.bias)  # Set biases to zero
model.apply(initialize_weights)

# the loss function
criterion = nn.MSELoss()

# the optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
num_epochs = 10000
loss_train = []
loss_test = []
for epoch in range(num_epochs):
    optimizer.zero_grad()  # Clear previous gradients
    outputs = model(x_train.to("cpu"))  # Forward pass
    loss = criterion(outputs.to('cpu'), y_train.to('cpu'))  # Compute loss
    loss_train.append(loss.item())
    loss.backward()  # Backpropagation
    optimizer.step()  # Update weights
    #
    with torch.no_grad():
        loss = criterion(model(x_test), y_test)
        loss_test.append(loss.item())
    
    if (epoch+1) % 100 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss_train: {loss_train[-1]:.4f}, Loss_test: {loss_test[-1]:.4f}')
# Out:
# Epoch [100/10000], Loss_train: 0.3918, Loss_test: 0.3913
# Epoch [200/10000], Loss_train: 0.2451, Loss_test: 0.2410
# Epoch [300/10000], Loss_train: 0.1956, Loss_test: 0.1911
# Epoch [400/10000], Loss_train: 0.1711, Loss_test: 0.1663
# Epoch [500/10000], Loss_train: 0.1572, Loss_test: 0.1525
# Epoch [600/10000], Loss_train: 0.1468, Loss_test: 0.1410
# Epoch [700/10000], Loss_train: 0.1384, Loss_test: 0.1323
# Epoch [800/10000], Loss_train: 0.1313, Loss_test: 0.1251
# Epoch [900/10000], Loss_train: 0.1251, Loss_test: 0.1187
# Epoch [1000/10000], Loss_train: 0.1227, Loss_test: 0.1192
# Epoch [1100/10000], Loss_train: 0.1113, Loss_test: 0.1067
# Epoch [1200/10000], Loss_train: 0.1063, Loss_test: 0.1010
# Epoch [1300/10000], Loss_train: 0.1024, Loss_test: 0.0957
# Epoch [1400/10000], Loss_train: 0.0972, Loss_test: 0.0930
# Epoch [1500/10000], Loss_train: 0.0941, Loss_test: 0.0894
# Epoch [1600/10000], Loss_train: 0.0919, Loss_test: 0.0875
# Epoch [1700/10000], Loss_train: 0.0928, Loss_test: 0.0869
# Epoch [1800/10000], Loss_train: 0.0928, Loss_test: 0.0847
# Epoch [1900/10000], Loss_train: 0.0883, Loss_test: 0.0844
# Epoch [2000/10000], Loss_train: 0.0862, Loss_test: 0.0819
# Epoch [2100/10000], Loss_train: 0.0853, Loss_test: 0.0809
# Epoch [2200/10000], Loss_train: 0.0844, Loss_test: 0.0801
# Epoch [2300/10000], Loss_train: 0.0836, Loss_test: 0.0800
# Epoch [2400/10000], Loss_train: 0.0828, Loss_test: 0.0785
# Epoch [2500/10000], Loss_train: 0.0821, Loss_test: 0.0778
# Epoch [2600/10000], Loss_train: 0.0814, Loss_test: 0.0771
# Epoch [2700/10000], Loss_train: 0.0807, Loss_test: 0.0764
# Epoch [2800/10000], Loss_train: 0.0802, Loss_test: 0.0758
# Epoch [2900/10000], Loss_train: 0.0798, Loss_test: 0.0757
# Epoch [3000/10000], Loss_train: 0.0810, Loss_test: 0.0778
# Epoch [3100/10000], Loss_train: 0.0786, Loss_test: 0.0742
# Epoch [3200/10000], Loss_train: 0.0782, Loss_test: 0.0738
# Epoch [3300/10000], Loss_train: 0.0801, Loss_test: 0.0741
# Epoch [3400/10000], Loss_train: 0.0811, Loss_test: 0.0739
# Epoch [3500/10000], Loss_train: 0.0860, Loss_test: 0.0787
# Epoch [3600/10000], Loss_train: 0.0768, Loss_test: 0.0731
# Epoch [3700/10000], Loss_train: 0.0772, Loss_test: 0.0730
# Epoch [3800/10000], Loss_train: 0.0763, Loss_test: 0.0721
# Epoch [3900/10000], Loss_train: 0.0769, Loss_test: 0.0721
# Epoch [4000/10000], Loss_train: 0.0758, Loss_test: 0.0713
# Epoch [4100/10000], Loss_train: 0.0778, Loss_test: 0.0722
# Epoch [4200/10000], Loss_train: 0.0825, Loss_test: 0.0799
# Epoch [4300/10000], Loss_train: 0.0767, Loss_test: 0.0730
# Epoch [4400/10000], Loss_train: 0.0749, Loss_test: 0.0705
# Epoch [4500/10000], Loss_train: 0.0748, Loss_test: 0.0704
# Epoch [4600/10000], Loss_train: 0.0751, Loss_test: 0.0705
# Epoch [4700/10000], Loss_train: 0.0747, Loss_test: 0.0703
# Epoch [4800/10000], Loss_train: 0.0751, Loss_test: 0.0710
# Epoch [4900/10000], Loss_train: 0.0670, Loss_test: 0.0630
# Epoch [5000/10000], Loss_train: 0.0653, Loss_test: 0.0612
# Epoch [5100/10000], Loss_train: 0.0630, Loss_test: 0.0594
# Epoch [5200/10000], Loss_train: 0.0606, Loss_test: 0.0570
# Epoch [5300/10000], Loss_train: 0.0582, Loss_test: 0.0548
# Epoch [5400/10000], Loss_train: 0.0777, Loss_test: 0.0820
# Epoch [5500/10000], Loss_train: 0.0513, Loss_test: 0.0481
# Epoch [5600/10000], Loss_train: 0.0494, Loss_test: 0.0468
# Epoch [5700/10000], Loss_train: 0.0431, Loss_test: 0.0404
# Epoch [5800/10000], Loss_train: 0.0387, Loss_test: 0.0360
# Epoch [5900/10000], Loss_train: 0.0348, Loss_test: 0.0319
# Epoch [6000/10000], Loss_train: 0.0313, Loss_test: 0.0274
# Epoch [6100/10000], Loss_train: 0.0276, Loss_test: 0.0246
# Epoch [6200/10000], Loss_train: 0.0286, Loss_test: 0.0229
# Epoch [6300/10000], Loss_train: 0.0185, Loss_test: 0.0163
# Epoch [6400/10000], Loss_train: 0.0156, Loss_test: 0.0131
# Epoch [6500/10000], Loss_train: 0.0164, Loss_test: 0.0132
# Epoch [6600/10000], Loss_train: 0.0104, Loss_test: 0.0086
# Epoch [6700/10000], Loss_train: 0.0083, Loss_test: 0.0065
# Epoch [6800/10000], Loss_train: 0.0071, Loss_test: 0.0052
# Epoch [6900/10000], Loss_train: 0.0061, Loss_test: 0.0044
# Epoch [7000/10000], Loss_train: 0.0088, Loss_test: 0.0091
# Epoch [7100/10000], Loss_train: 0.0049, Loss_test: 0.0030
# Epoch [7200/10000], Loss_train: 0.0046, Loss_test: 0.0027
# Epoch [7300/10000], Loss_train: 0.0054, Loss_test: 0.0039
# Epoch [7400/10000], Loss_train: 0.0053, Loss_test: 0.0025
# Epoch [7500/10000], Loss_train: 0.0111, Loss_test: 0.0056
# Epoch [7600/10000], Loss_train: 0.0076, Loss_test: 0.0066
# Epoch [7700/10000], Loss_train: 0.0037, Loss_test: 0.0018
# Epoch [7800/10000], Loss_train: 0.0036, Loss_test: 0.0016
# Epoch [7900/10000], Loss_train: 0.0036, Loss_test: 0.0016
# Epoch [8000/10000], Loss_train: 0.0042, Loss_test: 0.0019
# Epoch [8100/10000], Loss_train: 0.0047, Loss_test: 0.0046
# Epoch [8200/10000], Loss_train: 0.0035, Loss_test: 0.0014
# Epoch [8300/10000], Loss_train: 0.0034, Loss_test: 0.0014
# Epoch [8400/10000], Loss_train: 0.0038, Loss_test: 0.0015
# Epoch [8500/10000], Loss_train: 0.0075, Loss_test: 0.0045
# Epoch [8600/10000], Loss_train: 0.0112, Loss_test: 0.0109
# Epoch [8700/10000], Loss_train: 0.0050, Loss_test: 0.0036
# Epoch [8800/10000], Loss_train: 0.0035, Loss_test: 0.0015
# Epoch [8900/10000], Loss_train: 0.0034, Loss_test: 0.0013
# Epoch [9000/10000], Loss_train: 0.0033, Loss_test: 0.0012
# Epoch [9100/10000], Loss_train: 0.0033, Loss_test: 0.0012
# Epoch [9200/10000], Loss_train: 0.0039, Loss_test: 0.0015
# Epoch [9300/10000], Loss_train: 0.0057, Loss_test: 0.0016
# Epoch [9400/10000], Loss_train: 0.0035, Loss_test: 0.0015
# Epoch [9500/10000], Loss_train: 0.0033, Loss_test: 0.0012
# Epoch [9600/10000], Loss_train: 0.0034, Loss_test: 0.0013
# Epoch [9700/10000], Loss_train: 0.0034, Loss_test: 0.0013
# Epoch [9800/10000], Loss_train: 0.0032, Loss_test: 0.0012
# Epoch [9900/10000], Loss_train: 0.0033, Loss_test: 0.0012
# Epoch [10000/10000], Loss_train: 0.0067, Loss_test: 0.0021

# %% [markdown]
# **Notes:**
# - ```optimizer.zero_grad()``` clears old gradients to prevent accumulation.
# - ```loss.backward()``` computes gradients using backpropagation.
# - ```optimizer.step()``` updates parameters.

# %%
import matplotlib.pyplot as plt

y_pred = model(x_test).detach().numpy()
#
fig, axes = plt.subplots(1, 3, figsize=(12, 4)) 
# First subplot
axes[0].scatter(x_train, y_train, label="train data", color="r")
axes[0].set_title("The training data")
axes[0].legend()
#
# Second subplot
axes[1].plot(x_test, y_test, label="true", color="r")
axes[1].plot(x_test, y_pred, label="pred", color="b")
axes[1].set_title("The prediction")
axes[1].legend()
#
# Third subplot
axes[2].plot(loss_train, label="training loss", color="r")
axes[2].plot(loss_test, label="testing loss", color="b")
# axes[2].semilogy(loss_train, label="training loss", color="r")
# axes[2].semilogy(loss_test, label="testing loss", color="b")
axes[2].set_title("Loss")
axes[2].legend()
#
plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %%
import matplotlib.pyplot as plt

y_pred = model(x_test).detach().numpy()
#
fig, axes = plt.subplots(1, 3, figsize=(12, 4)) 
# First subplot
axes[0].scatter(x_train, y_train, label="train data", color="r")
axes[0].set_title("The training data")
axes[0].legend()
#
# Second subplot
axes[1].plot(x_test, y_test, label="true", color="r")
axes[1].plot(x_test, y_pred, label="pred", color="b")
axes[1].set_title("The prediction")
axes[1].legend()
#
# Third subplot
# axes[2].plot(loss_train, label="training loss", color="r")
# axes[2].plot(loss_test, label="testing loss", color="b")
axes[2].semilogy(loss_train, label="training loss", color="r")
axes[2].semilogy(loss_test, label="testing loss", color="b")
axes[2].set_title("Loss")
axes[2].legend()
#
plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %% [markdown]
# ## (6) Saving and Loading a Trained Model

# %% [markdown]
# ### (6.1) Save only the trained parameters with ```state_dict```

# %%
torch.save(model.state_dict(), 'model_state.pth')  # Saves only model weights

# %% [markdown]
# #### Loading a Model for Testing
#
# **Note:**  ```eval()``` disables dropout and batch normalization effects for inference.

# %%
model_load = SelfNN(arch=[1, 40, 40, 40, 40, 1], activation=nn.ReLU())  # Recreate model
trained_param = torch.load('model_state.pth')
model_load.load_state_dict(trained_param)  # Load trained weights
model_load.eval()  # Set model to evaluation mode

#########
import matplotlib.pyplot as plt

y_pred = model_load(x_test).detach().numpy()
#
plt.figure()
plt.plot(x_test, y_test, label="true", color="r")
plt.plot(x_test, y_pred, label="pred", color="b")
plt.title("The prediction with loaded model")
plt.legend()
#
plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %% [markdown]
# ### (6.2) Saving both the model parameters and structure

# %%
torch.save(model, 'model_all.pth')

# %% [markdown]
# **load the model without specifying its structrue**

# %%
model_load = torch.load('model_all.pth')
print(model_load)
model_load.eval()  # Set model to evaluation mode

#########
import matplotlib.pyplot as plt

y_pred = model_load(x_test).detach().numpy()
#
plt.figure()
plt.plot(x_test, y_test, label="true", color="r")
plt.plot(x_test, y_pred, label="pred", color="b")
plt.title("The prediction with loaded model")
plt.legend()
plt.tight_layout() 
plt.show()
# Out:
# SelfNN(
#   (nn_model): Sequential(
#     (0): Linear(in_features=1, out_features=40, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=40, out_features=40, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=40, out_features=40, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=40, out_features=40, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=40, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ## (7) Additional Best Practices for Training DNNs

# %% [markdown]
# ### (7.1) Use Mini-batch Training Instead of Full Dataset
#
# Instead of using the full dataset at once, we use torch.utils.data.DataLoader to create batches.

# %%
import h5py
import numpy as np
import torch
import matplotlib.pyplot as plt 
#
with h5py.File('regression_1d.h5', 'r') as f:
    x_test = torch.tensor(np.array(f['x_test']))
    y_test = torch.tensor(np.array(f['y_test']))
    x_train = torch.tensor(np.array(f['x_train']))
    y_train = torch.tensor(np.array(f['y_train']))

# %%
from torch.utils.data import Dataset, DataLoader
#
class MyDataset(Dataset):

    def __init__(self, x, y):
        self.x = x.reshape(-1, 1)
        self.y = y.reshape(-1, 1)

    def __getitem__(self, index):
        return self.x[index], self.y[index]

    def __len__(self):
        return self.x.shape[0]
        
dataloader = DataLoader(MyDataset(x_train, y_train), batch_size=100, shuffle=True)
print('The length of dataloader:', len(dataloader))
# Out:
# The length of dataloader: 25

# %%
from torch import nn
import torch.optim as optim
import torch.nn.init as init
#
torch.manual_seed(1234)

class SelfNN(nn.Module):

    def __init__(self, arch:list, activation=nn.ReLU()):
        super(SelfNN, self).__init__()
        ##
        self.nn_model = nn.Sequential()
        input_size = arch[0]
        #
        for hidden_size in arch[1:-1]:
            self.nn_model.append(nn.Linear(input_size, hidden_size))
            self.nn_model.append(activation)
            input_size = hidden_size
        #
        self.nn_model.append(nn.Linear(hidden_size, arch[-1]))

    def forward(self, x):
        '''
        Input:
            x: size(batch_size, x_size)
        Output:
            y: size(batch_size, out_size)
        '''
        y = self.nn_model(x)
        
        return y

# Define model
model = SelfNN(arch=[1, 40, 40, 40, 1], activation=nn.ReLU())

# Apply initialization to model
def initialize_weights(m):
    if isinstance(m, nn.Linear):
        init.xavier_uniform_(m.weight)  
        init.zeros_(m.bias) 
model.apply(initialize_weights)

# the loss function
criterion = nn.MSELoss()

# the optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
num_epochs = 5000
loss_train = []
loss_test = []
for epoch in range(num_epochs):
    loss_sum = 0.
    for batch_x, batch_y in dataloader: # training with batch (Once the loop finishes, the dataset will be read once in its entirety)
        optimizer.zero_grad()  
        outputs = model(batch_x) 
        loss = criterion(outputs, batch_y)  
        loss_sum += loss.item()
        loss.backward()  
        optimizer.step()
    loss_train.append(loss_sum/len(dataloader))
    #
    with torch.no_grad():
        loss = criterion(model(x_test), y_test)
        loss_test.append(loss.item())
    
    if (epoch+1) % 100 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss_train: {loss_train[-1]:.4f}, Loss_test: {loss_test[-1]:.4f}')
# Out:
# Epoch [100/5000], Loss_train: 0.1567, Loss_test: 0.1587
# Epoch [200/5000], Loss_train: 0.1413, Loss_test: 0.1317
# Epoch [300/5000], Loss_train: 0.1059, Loss_test: 0.0976
# Epoch [400/5000], Loss_train: 0.0905, Loss_test: 0.0813
# Epoch [500/5000], Loss_train: 0.0832, Loss_test: 0.0844
# Epoch [600/5000], Loss_train: 0.0843, Loss_test: 0.0815
# Epoch [700/5000], Loss_train: 0.0825, Loss_test: 0.0767
# Epoch [800/5000], Loss_train: 0.0792, Loss_test: 0.0761
# Epoch [900/5000], Loss_train: 0.0796, Loss_test: 0.0728
# Epoch [1000/5000], Loss_train: 0.0765, Loss_test: 0.0727
# Epoch [1100/5000], Loss_train: 0.0670, Loss_test: 0.0596
# Epoch [1200/5000], Loss_train: 0.0065, Loss_test: 0.0039
# Epoch [1300/5000], Loss_train: 0.0051, Loss_test: 0.0023
# Epoch [1400/5000], Loss_train: 0.0054, Loss_test: 0.0029
# Epoch [1500/5000], Loss_train: 0.0042, Loss_test: 0.0019
# Epoch [1600/5000], Loss_train: 0.0059, Loss_test: 0.0049
# Epoch [1700/5000], Loss_train: 0.0038, Loss_test: 0.0017
# Epoch [1800/5000], Loss_train: 0.0059, Loss_test: 0.0041
# Epoch [1900/5000], Loss_train: 0.0035, Loss_test: 0.0009
# Epoch [2000/5000], Loss_train: 0.0035, Loss_test: 0.0014
# Epoch [2100/5000], Loss_train: 0.0038, Loss_test: 0.0027
# Epoch [2200/5000], Loss_train: 0.0039, Loss_test: 0.0011
# Epoch [2300/5000], Loss_train: 0.0033, Loss_test: 0.0011
# Epoch [2400/5000], Loss_train: 0.0035, Loss_test: 0.0015
# Epoch [2500/5000], Loss_train: 0.0038, Loss_test: 0.0021
# Epoch [2600/5000], Loss_train: 0.0031, Loss_test: 0.0012
# Epoch [2700/5000], Loss_train: 0.0035, Loss_test: 0.0014
# Epoch [2800/5000], Loss_train: 0.0037, Loss_test: 0.0007
# Epoch [2900/5000], Loss_train: 0.0043, Loss_test: 0.0008
# Epoch [3000/5000], Loss_train: 0.0036, Loss_test: 0.0026
# Epoch [3100/5000], Loss_train: 0.0036, Loss_test: 0.0038
# Epoch [3200/5000], Loss_train: 0.0033, Loss_test: 0.0015
# Epoch [3300/5000], Loss_train: 0.0044, Loss_test: 0.0007
# Epoch [3400/5000], Loss_train: 0.0037, Loss_test: 0.0018
# Epoch [3500/5000], Loss_train: 0.0038, Loss_test: 0.0014
# Epoch [3600/5000], Loss_train: 0.0037, Loss_test: 0.0014
# Epoch [3700/5000], Loss_train: 0.0034, Loss_test: 0.0006
# Epoch [3800/5000], Loss_train: 0.0033, Loss_test: 0.0012
# Epoch [3900/5000], Loss_train: 0.0031, Loss_test: 0.0011
# Epoch [4000/5000], Loss_train: 0.0034, Loss_test: 0.0011
# Epoch [4100/5000], Loss_train: 0.0033, Loss_test: 0.0009
# Epoch [4200/5000], Loss_train: 0.0035, Loss_test: 0.0011
# Epoch [4300/5000], Loss_train: 0.0038, Loss_test: 0.0018
# Epoch [4400/5000], Loss_train: 0.0033, Loss_test: 0.0013
# Epoch [4500/5000], Loss_train: 0.0032, Loss_test: 0.0009
# Epoch [4600/5000], Loss_train: 0.0033, Loss_test: 0.0008
# Epoch [4700/5000], Loss_train: 0.0028, Loss_test: 0.0010
# Epoch [4800/5000], Loss_train: 0.0040, Loss_test: 0.0017
# Epoch [4900/5000], Loss_train: 0.0033, Loss_test: 0.0009
# Epoch [5000/5000], Loss_train: 0.0037, Loss_test: 0.0023

# %%
import matplotlib.pyplot as plt

y_pred = model(x_test).detach().numpy()
#
fig, axes = plt.subplots(1, 3, figsize=(12, 4)) 
# First subplot
axes[0].scatter(x_train, y_train, label="train data", color="r")
axes[0].set_title("The training data")
axes[0].legend()
#
# Second subplot
axes[1].plot(x_test, y_test, label="true", color="r")
axes[1].plot(x_test, y_pred, label="pred", color="b")
axes[1].set_title("The prediction")
axes[1].legend()
#
# Third subplot
axes[2].semilogy(loss_train, label="training loss", color="r")
axes[2].semilogy(loss_test, label="testing loss", color="b")
axes[2].set_title("Loss")
axes[2].legend()
plt.tight_layout()  
plt.show()

# %% [markdown]
# ### (7.2) Use Learning Rate Scheduling for Better Convergence

# %%
import h5py
import numpy as np
import torch
import matplotlib.pyplot as plt 
from torch.utils.data import Dataset, DataLoader
#
with h5py.File('regression_1d.h5', 'r') as f:
    x_test = torch.tensor(np.array(f['x_test']))
    y_test = torch.tensor(np.array(f['y_test']))
    x_train = torch.tensor(np.array(f['x_train']))
    y_train = torch.tensor(np.array(f['y_train']))

# %%
from torch import nn
import torch.optim as optim
import torch.nn.init as init
#
torch.manual_seed(1234)

def initialize_weights(m):
    if isinstance(m, nn.Linear):
        init.xavier_uniform_(m.weight) 
        init.zeros_(m.bias) 

class SelfNN(nn.Module):

    def __init__(self, arch:list, activation=nn.ReLU()):
        super(SelfNN, self).__init__()
        ##
        self.nn_model = nn.Sequential()
        input_size = arch[0]
        #
        for hidden_size in arch[1:-1]:
            self.nn_model.append(nn.Linear(input_size, hidden_size))
            self.nn_model.append(activation)
            input_size = hidden_size
        #
        self.nn_model.append(nn.Linear(hidden_size, arch[-1]))

    def forward(self, x):
        '''
        Input:
            x: size(batch_size, x_size)
        Output:
            y: size(batch_size, out_size)
        '''
        y = self.nn_model(x)
        
        return y

# Define model
model = SelfNN(arch=[1, 40, 40, 40, 40, 40, 40, 1], activation=nn.ReLU())

# Apply initialization to model
model.apply(initialize_weights)

# the loss function
criterion = nn.MSELoss()

# the optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001)

# the scheduler
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1000, gamma=0.5)

# Training loop
num_epochs = 5000
loss_train = []
loss_test = []
for epoch in range(num_epochs):
    optimizer.zero_grad()  
    outputs = model(x_train) 
    loss = criterion(outputs, y_train)  
    loss.backward()  
    optimizer.step()  
    loss_train.append(loss.item())
    #
    scheduler.step()  # Adjust learning rate
    #
    with torch.no_grad():
        loss = criterion(model(x_test), y_test)
        loss_test.append(loss.item())
    
    if (epoch+1) % 100 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss_train: {loss_train[-1]:.4f}, Loss_test: {loss_test[-1]:.4f}, lr: {scheduler.optimizer.param_groups[0]["lr"]}')
# Out:
# Epoch [100/5000], Loss_train: 0.2988, Loss_test: 0.2932, lr: 0.001
# Epoch [200/5000], Loss_train: 0.1722, Loss_test: 0.1675, lr: 0.001
# Epoch [300/5000], Loss_train: 0.1155, Loss_test: 0.1095, lr: 0.001
# Epoch [400/5000], Loss_train: 0.0862, Loss_test: 0.0813, lr: 0.001
# Epoch [500/5000], Loss_train: 0.0783, Loss_test: 0.0739, lr: 0.001
# Epoch [600/5000], Loss_train: 0.0704, Loss_test: 0.0657, lr: 0.001
# Epoch [700/5000], Loss_train: 0.0564, Loss_test: 0.0531, lr: 0.001
# Epoch [800/5000], Loss_train: 0.0400, Loss_test: 0.0374, lr: 0.001
# Epoch [900/5000], Loss_train: 0.0213, Loss_test: 0.0188, lr: 0.001
# Epoch [1000/5000], Loss_train: 0.0144, Loss_test: 0.0108, lr: 0.0005
# Epoch [1100/5000], Loss_train: 0.0064, Loss_test: 0.0043, lr: 0.0005
# Epoch [1200/5000], Loss_train: 0.0047, Loss_test: 0.0026, lr: 0.0005
# Epoch [1300/5000], Loss_train: 0.0038, Loss_test: 0.0017, lr: 0.0005
# Epoch [1400/5000], Loss_train: 0.0033, Loss_test: 0.0012, lr: 0.0005
# Epoch [1500/5000], Loss_train: 0.0030, Loss_test: 0.0009, lr: 0.0005
# Epoch [1600/5000], Loss_train: 0.0028, Loss_test: 0.0007, lr: 0.0005
# Epoch [1700/5000], Loss_train: 0.0027, Loss_test: 0.0006, lr: 0.0005
# Epoch [1800/5000], Loss_train: 0.0028, Loss_test: 0.0008, lr: 0.0005
# Epoch [1900/5000], Loss_train: 0.0048, Loss_test: 0.0031, lr: 0.0005
# Epoch [2000/5000], Loss_train: 0.0029, Loss_test: 0.0009, lr: 0.00025
# Epoch [2100/5000], Loss_train: 0.0026, Loss_test: 0.0005, lr: 0.00025
# Epoch [2200/5000], Loss_train: 0.0026, Loss_test: 0.0005, lr: 0.00025
# Epoch [2300/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 0.00025
# Epoch [2400/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 0.00025
# Epoch [2500/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 0.00025
# Epoch [2600/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 0.00025
# Epoch [2700/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 0.00025
# Epoch [2800/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 0.00025
# Epoch [2900/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 0.00025
# Epoch [3000/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 0.000125
# Epoch [3100/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 0.000125
# Epoch [3200/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 0.000125
# Epoch [3300/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 0.000125
# Epoch [3400/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 0.000125
# Epoch [3500/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 0.000125
# Epoch [3600/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 0.000125
# Epoch [3700/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 0.000125
# Epoch [3800/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 0.000125
# Epoch [3900/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 0.000125
# Epoch [4000/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 6.25e-05
# Epoch [4100/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 6.25e-05
# Epoch [4200/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 6.25e-05
# Epoch [4300/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 6.25e-05
# Epoch [4400/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 6.25e-05
# Epoch [4500/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 6.25e-05
# Epoch [4600/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 6.25e-05
# Epoch [4700/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 6.25e-05
# Epoch [4800/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 6.25e-05
# Epoch [4900/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 6.25e-05
# Epoch [5000/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 3.125e-05

# %%
import matplotlib.pyplot as plt

y_pred = model(x_test).detach().numpy()
#
fig, axes = plt.subplots(1, 3, figsize=(12, 4)) 
# First subplot
axes[0].scatter(x_train, y_train, label="train data", color="r")
axes[0].set_title("The training data")
axes[0].legend()
#
# Second subplot
axes[1].plot(x_test, y_test, label="true", color="r")
axes[1].plot(x_test, y_pred, label="pred", color="b")
axes[1].set_title("The prediction")
axes[1].legend()
#
# Third subplot
axes[2].semilogy(loss_train, label="training loss", color="r")
axes[2].semilogy(loss_test, label="testing loss", color="b")
axes[2].set_title("Loss")
axes[2].legend()
plt.tight_layout() 
plt.show()

# %% [markdown]
# ### (7.3) Use Early Stopping to Prevent Overfitting
#
# Instead of training for a fixed number of epochs, stop early if the validation loss stops improving.

# %%
import torch 
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
#
torch.manual_seed(1234)

# Sample training data
x_train = torch.rand(100, 1)  # 100 samples, 1 features
y_train = torch.sin(2. * torch.pi * x_train) + 0.1 * torch.randn(100, 1)   # 100 target values

# Sample testiing data
x_test = torch.linspace(0, 1, 1000).view(-1, 1)
y_test = torch.sin(2. * torch.pi * x_test)   

#
plt.figure()
plt.plot(x_test, y_test, label=r'$y=sin(2\pi x)$', color='r')
plt.scatter(x_train, y_train, label=r'training data')
plt.legend()
plt.show()

# %%
from torch import nn
import torch.optim as optim
import torch.nn.init as init
#
torch.manual_seed(1234)

def initialize_weights(m):
    if isinstance(m, nn.Linear):
        init.xavier_uniform_(m.weight) 
        init.zeros_(m.bias) 

class SelfNN(nn.Module):

    def __init__(self, arch:list, activation=nn.ReLU()):
        super(SelfNN, self).__init__()
        ##
        self.nn_model = nn.Sequential()
        input_size = arch[0]
        #
        for hidden_size in arch[1:-1]:
            self.nn_model.append(nn.Linear(input_size, hidden_size))
            self.nn_model.append(activation)
            input_size = hidden_size
        #
        self.nn_model.append(nn.Linear(hidden_size, arch[-1]))

    def forward(self, x):
        '''
        Input:
            x: size(batch_size, x_size)
        Output:
            y: size(batch_size, out_size)
        '''
        y = self.nn_model(x)
        
        return y

# Define model
model = SelfNN(arch=[1, 10, 10, 10, 1], activation=nn.ReLU())

# Apply initialization to model
model.apply(initialize_weights)

# the loss function
criterion = nn.MSELoss()

# the optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
num_epochs = 5000
loss_train = []
loss_test = []
for epoch in range(num_epochs):
    optimizer.zero_grad()  
    outputs = model(x_train)  
    loss = criterion(outputs, y_train)  
    loss.backward()  
    optimizer.step()  
    loss_train.append(loss.item())
    #
    with torch.no_grad():
        loss = criterion(model(x_test), y_test)
        loss_test.append(loss.item())
    
    if (epoch+1) % 100 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss_train: {loss_train[-1]:.4f}, Loss_test: {loss_test[-1]:.4f}')
# Out:
# Epoch [100/5000], Loss_train: 0.3951, Loss_test: 0.3178
# Epoch [200/5000], Loss_train: 0.1174, Loss_test: 0.1378
# Epoch [300/5000], Loss_train: 0.0980, Loss_test: 0.1394
# Epoch [400/5000], Loss_train: 0.0922, Loss_test: 0.1313
# Epoch [500/5000], Loss_train: 0.0857, Loss_test: 0.1223
# Epoch [600/5000], Loss_train: 0.0783, Loss_test: 0.1123
# Epoch [700/5000], Loss_train: 0.0704, Loss_test: 0.1019
# Epoch [800/5000], Loss_train: 0.0627, Loss_test: 0.0908
# Epoch [900/5000], Loss_train: 0.0550, Loss_test: 0.0795
# Epoch [1000/5000], Loss_train: 0.0475, Loss_test: 0.0677
# Epoch [1100/5000], Loss_train: 0.0399, Loss_test: 0.0556
# Epoch [1200/5000], Loss_train: 0.0320, Loss_test: 0.0425
# Epoch [1300/5000], Loss_train: 0.0249, Loss_test: 0.0316
# Epoch [1400/5000], Loss_train: 0.0200, Loss_test: 0.0219
# Epoch [1500/5000], Loss_train: 0.0159, Loss_test: 0.0154
# Epoch [1600/5000], Loss_train: 0.0133, Loss_test: 0.0103
# Epoch [1700/5000], Loss_train: 0.0122, Loss_test: 0.0073
# Epoch [1800/5000], Loss_train: 0.0113, Loss_test: 0.0057
# Epoch [1900/5000], Loss_train: 0.0110, Loss_test: 0.0048
# Epoch [2000/5000], Loss_train: 0.0107, Loss_test: 0.0043
# Epoch [2100/5000], Loss_train: 0.0105, Loss_test: 0.0040
# Epoch [2200/5000], Loss_train: 0.0104, Loss_test: 0.0038
# Epoch [2300/5000], Loss_train: 0.0104, Loss_test: 0.0037
# Epoch [2400/5000], Loss_train: 0.0103, Loss_test: 0.0036
# Epoch [2500/5000], Loss_train: 0.0103, Loss_test: 0.0035
# Epoch [2600/5000], Loss_train: 0.0103, Loss_test: 0.0035
# Epoch [2700/5000], Loss_train: 0.0102, Loss_test: 0.0035
# Epoch [2800/5000], Loss_train: 0.0102, Loss_test: 0.0034
# Epoch [2900/5000], Loss_train: 0.0102, Loss_test: 0.0034
# Epoch [3000/5000], Loss_train: 0.0102, Loss_test: 0.0034
# Epoch [3100/5000], Loss_train: 0.0102, Loss_test: 0.0034
# Epoch [3200/5000], Loss_train: 0.0102, Loss_test: 0.0034
# Epoch [3300/5000], Loss_train: 0.0102, Loss_test: 0.0034
# Epoch [3400/5000], Loss_train: 0.0102, Loss_test: 0.0033
# Epoch [3500/5000], Loss_train: 0.0102, Loss_test: 0.0034
# Epoch [3600/5000], Loss_train: 0.0102, Loss_test: 0.0033
# Epoch [3700/5000], Loss_train: 0.0102, Loss_test: 0.0034
# Epoch [3800/5000], Loss_train: 0.0102, Loss_test: 0.0034
# Epoch [3900/5000], Loss_train: 0.0102, Loss_test: 0.0034
# Epoch [4000/5000], Loss_train: 0.0102, Loss_test: 0.0034
# Epoch [4100/5000], Loss_train: 0.0101, Loss_test: 0.0033
# Epoch [4200/5000], Loss_train: 0.0101, Loss_test: 0.0034
# Epoch [4300/5000], Loss_train: 0.0101, Loss_test: 0.0033
# Epoch [4400/5000], Loss_train: 0.0101, Loss_test: 0.0033
# Epoch [4500/5000], Loss_train: 0.0101, Loss_test: 0.0033
# Epoch [4600/5000], Loss_train: 0.0101, Loss_test: 0.0033
# Epoch [4700/5000], Loss_train: 0.0101, Loss_test: 0.0033
# Epoch [4800/5000], Loss_train: 0.0101, Loss_test: 0.0033
# Epoch [4900/5000], Loss_train: 0.0101, Loss_test: 0.0034
# Epoch [5000/5000], Loss_train: 0.0101, Loss_test: 0.0034

# %%
import matplotlib.pyplot as plt

y_pred = model(x_test).detach().numpy()
#
fig, axes = plt.subplots(1, 3, figsize=(12, 4)) 
# First subplot
axes[0].scatter(x_train, y_train, label="train data", color="r")
axes[0].set_title("The training data")
axes[0].legend()
#
# Second subplot
axes[1].plot(x_test, y_test, label="true", color="r")
axes[1].plot(x_test, y_pred, label="pred", color="b")
axes[1].set_title("The prediction")
axes[1].legend()
#
# Third subplot
axes[2].semilogy(loss_train, label="training loss", color="r")
axes[2].semilogy(loss_test, label="testing loss", color="b")
axes[2].set_title("Loss")
axes[2].legend()
plt.tight_layout() 
plt.show()

# %%
from torch import nn
import torch.optim as optim
import torch.nn.init as init
#
torch.manual_seed(1234)

def initialize_weights(m):
    if isinstance(m, nn.Linear):
        init.xavier_uniform_(m.weight)  
        init.zeros_(m.bias) 

class SelfNN(nn.Module):

    def __init__(self, arch:list, activation=nn.ReLU()):
        super(SelfNN, self).__init__()
        ##
        self.nn_model = nn.Sequential()
        input_size = arch[0]
        #
        for hidden_size in arch[1:-1]:
            self.nn_model.append(nn.Linear(input_size, hidden_size))
            self.nn_model.append(activation)
            input_size = hidden_size
        #
        self.nn_model.append(nn.Linear(hidden_size, arch[-1]))

    def forward(self, x):
        '''
        Input:
            x: size(batch_size, x_size)
        Output:
            y: size(batch_size, out_size)
        '''
        y = self.nn_model(x)
        
        return y

# Define model
model = SelfNN(arch=[1, 60, 60, 60, 60, 60, 60, 1], activation=nn.ReLU())

# Apply initialization to model
model.apply(initialize_weights)

# the loss function
criterion = nn.MSELoss()

# the optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
num_epochs = 5000
loss_train = []
loss_test = []
# Setting for early stop
best_loss = float('inf')
patience = 20
counter = 0
#
for epoch in range(num_epochs):
    optimizer.zero_grad()  
    outputs = model(x_train) 
    loss = criterion(outputs, y_train)  
    # Checking the condition of early stopping
    if loss.item() < best_loss:
        best_loss = loss.item()
        counter = 0
    else:
        counter += 1
    if counter >= patience:
        print("Early stopping triggered")
        break
    #
    loss.backward() 
    optimizer.step()
    loss_train.append(loss.item())
    #
    with torch.no_grad():
        loss = criterion(model(x_test), y_test)
        loss_test.append(loss.item())
    
    if (epoch+1) % 100 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss_train: {loss_train[-1]:.4f}, Loss_test: {loss_test[-1]:.4f}')
# Out:
# Epoch [100/5000], Loss_train: 0.0171, Loss_test: 0.0146
# Epoch [200/5000], Loss_train: 0.0099, Loss_test: 0.0027
# Early stopping triggered

# %%
import matplotlib.pyplot as plt

y_pred = model(x_test).detach().numpy()
#
fig, axes = plt.subplots(1, 3, figsize=(12, 4)) 
# First subplot
axes[0].scatter(x_train, y_train, label="train data", color="r")
axes[0].set_title("The training data")
axes[0].legend()
#
# Second subplot
axes[1].plot(x_test, y_test, label="true", color="r")
axes[1].plot(x_test, y_pred, label="pred", color="b")
axes[1].set_title("The prediction")
axes[1].legend()
#
# Third subplot
axes[2].semilogy(loss_train, label="training loss", color="r")
axes[2].semilogy(loss_test, label="testing loss", color="b")
axes[2].set_title("Loss")
axes[2].legend()
plt.tight_layout()  
plt.show()

# %% [markdown]
# ## (8) Summary

# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
#
torch.manual_seed(1234)

########################## Step 1: Define the Neural Network
class SelfNN(nn.Module):

    def __init__(self, arch:list, activation=nn.ReLU()):
        super(SelfNN, self).__init__()
        ##
        self.nn_model = nn.Sequential()
        input_size = arch[0]
        #
        for hidden_size in arch[1:-1]:
            self.nn_model.append(nn.Linear(input_size, hidden_size))
            self.nn_model.append(activation)
            input_size = hidden_size
        #
        self.nn_model.append(nn.Linear(hidden_size, arch[-1]))

    def forward(self, x):
        '''
        Input:
            x: size(batch_size, x_size)
        Output:
            y: size(batch_size, out_size)
        '''
        y = self.nn_model(x)
        
        return y

########################## Step 2: load data
with h5py.File('regression_1d.h5', 'r') as f:
    x_test = torch.tensor(np.array(f['x_test']))
    y_test = torch.tensor(np.array(f['y_test']))
    x_train = torch.tensor(np.array(f['x_train']))
    y_train = torch.tensor(np.array(f['y_train']))

########################## Create DataLoader for Mini-Batch Training
class MyDataset(Dataset):

    def __init__(self, x, y):
        self.x = x.reshape(-1, 1)
        self.y = y.reshape(-1, 1)

    def __getitem__(self, index):
        return self.x[index], self.y[index]

    def __len__(self):
        return self.x.shape[0]
        
dataloader = DataLoader(MyDataset(x_train, y_train), batch_size=100, shuffle=True)

########################## Step 3: Initialize Model, Loss Function, and Optimizer
model = SelfNN(arch=[1, 60, 60, 60, 60, 1], activation=nn.ReLU())
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1000, gamma=0.5)

########################## Step 4: Train the Model
num_epochs = 5000
loss_train = []
loss_test = []
for epoch in range(num_epochs):
    loss_sum = 0.
    for batch_x, batch_y in dataloader:
        optimizer.zero_grad()   # Clear gradients
        outputs = model(batch_x)  # Forward pass
        loss = criterion(outputs, batch_y)  # Compute loss
        loss.backward()  # Backpropagation
        optimizer.step()  # Update weights 
        loss_sum += loss.item()
    loss_train.append(loss_sum/len(dataloader))
    #
    scheduler.step()  # Adjust learning rate
    #
    with torch.no_grad():
        loss = criterion(model(x_test), y_test)
        loss_test.append(loss.item())
        
    if (epoch+1) % 100 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss_train: {loss_train[-1]:.4f}, Loss_test: {loss_test[-1]:.4f}, lr: {scheduler.optimizer.param_groups[0]["lr"]}')

##########################  Step 5: Save the Model
torch.save(model, 'model_all.pth')

##########################  Step 6: Load the Model for Testing
loaded_model = torch.load('model_all.pth')
loaded_model.eval()  # Set to evaluation mode

########################## Step 7: Test the Model
y_pred = loaded_model(x_test).detach().numpy()  # Make predictions
#
plt.figure()
plt.plot(x_test, y_test, label="true", color="r")
plt.plot(x_test, y_pred, label="pred.", color="b")
plt.title("The prediction with loaded model")
plt.legend()
plt.tight_layout() 
plt.show()
# Out:
# Epoch [100/5000], Loss_train: 0.0064, Loss_test: 0.0025, lr: 0.001
# Epoch [200/5000], Loss_train: 0.0043, Loss_test: 0.0013, lr: 0.001
# Epoch [300/5000], Loss_train: 0.0050, Loss_test: 0.0024, lr: 0.001
# Epoch [400/5000], Loss_train: 0.0043, Loss_test: 0.0027, lr: 0.001
# Epoch [500/5000], Loss_train: 0.0044, Loss_test: 0.0013, lr: 0.001
# Epoch [600/5000], Loss_train: 0.0069, Loss_test: 0.0026, lr: 0.001
# Epoch [700/5000], Loss_train: 0.0038, Loss_test: 0.0009, lr: 0.001
# Epoch [800/5000], Loss_train: 0.0032, Loss_test: 0.0020, lr: 0.001
# Epoch [900/5000], Loss_train: 0.0046, Loss_test: 0.0019, lr: 0.001
# Epoch [1000/5000], Loss_train: 0.0034, Loss_test: 0.0011, lr: 0.0005
# Epoch [1100/5000], Loss_train: 0.0031, Loss_test: 0.0005, lr: 0.0005
# Epoch [1200/5000], Loss_train: 0.0028, Loss_test: 0.0004, lr: 0.0005
# Epoch [1300/5000], Loss_train: 0.0028, Loss_test: 0.0004, lr: 0.0005
# Epoch [1400/5000], Loss_train: 0.0033, Loss_test: 0.0005, lr: 0.0005
# Epoch [1500/5000], Loss_train: 0.0028, Loss_test: 0.0004, lr: 0.0005
# Epoch [1600/5000], Loss_train: 0.0029, Loss_test: 0.0005, lr: 0.0005
# Epoch [1700/5000], Loss_train: 0.0032, Loss_test: 0.0005, lr: 0.0005
# Epoch [1800/5000], Loss_train: 0.0028, Loss_test: 0.0004, lr: 0.0005
# Epoch [1900/5000], Loss_train: 0.0027, Loss_test: 0.0008, lr: 0.0005
# Epoch [2000/5000], Loss_train: 0.0028, Loss_test: 0.0006, lr: 0.00025
# Epoch [2100/5000], Loss_train: 0.0026, Loss_test: 0.0003, lr: 0.00025
# Epoch [2200/5000], Loss_train: 0.0027, Loss_test: 0.0003, lr: 0.00025
# Epoch [2300/5000], Loss_train: 0.0026, Loss_test: 0.0004, lr: 0.00025
# Epoch [2400/5000], Loss_train: 0.0026, Loss_test: 0.0006, lr: 0.00025
# Epoch [2500/5000], Loss_train: 0.0026, Loss_test: 0.0004, lr: 0.00025
# Epoch [2600/5000], Loss_train: 0.0026, Loss_test: 0.0002, lr: 0.00025
# Epoch [2700/5000], Loss_train: 0.0026, Loss_test: 0.0003, lr: 0.00025
# Epoch [2800/5000], Loss_train: 0.0026, Loss_test: 0.0003, lr: 0.00025
# Epoch [2900/5000], Loss_train: 0.0026, Loss_test: 0.0003, lr: 0.00025
# Epoch [3000/5000], Loss_train: 0.0025, Loss_test: 0.0005, lr: 0.000125
# Epoch [3100/5000], Loss_train: 0.0025, Loss_test: 0.0003, lr: 0.000125
# Epoch [3200/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 0.000125
# Epoch [3300/5000], Loss_train: 0.0025, Loss_test: 0.0003, lr: 0.000125
# Epoch [3400/5000], Loss_train: 0.0024, Loss_test: 0.0004, lr: 0.000125
# Epoch [3500/5000], Loss_train: 0.0025, Loss_test: 0.0003, lr: 0.000125
# Epoch [3600/5000], Loss_train: 0.0024, Loss_test: 0.0003, lr: 0.000125
# Epoch [3700/5000], Loss_train: 0.0025, Loss_test: 0.0004, lr: 0.000125
# Epoch [3800/5000], Loss_train: 0.0025, Loss_test: 0.0003, lr: 0.000125
# Epoch [3900/5000], Loss_train: 0.0024, Loss_test: 0.0002, lr: 0.000125
# Epoch [4000/5000], Loss_train: 0.0025, Loss_test: 0.0003, lr: 6.25e-05
# Epoch [4100/5000], Loss_train: 0.0024, Loss_test: 0.0002, lr: 6.25e-05
# Epoch [4200/5000], Loss_train: 0.0024, Loss_test: 0.0003, lr: 6.25e-05
# Epoch [4300/5000], Loss_train: 0.0024, Loss_test: 0.0002, lr: 6.25e-05
# Epoch [4400/5000], Loss_train: 0.0024, Loss_test: 0.0002, lr: 6.25e-05
# Epoch [4500/5000], Loss_train: 0.0024, Loss_test: 0.0002, lr: 6.25e-05
# Epoch [4600/5000], Loss_train: 0.0024, Loss_test: 0.0003, lr: 6.25e-05
# Epoch [4700/5000], Loss_train: 0.0024, Loss_test: 0.0002, lr: 6.25e-05
# Epoch [4800/5000], Loss_train: 0.0024, Loss_test: 0.0002, lr: 6.25e-05
# Epoch [4900/5000], Loss_train: 0.0024, Loss_test: 0.0002, lr: 6.25e-05
# Epoch [5000/5000], Loss_train: 0.0023, Loss_test: 0.0003, lr: 3.125e-05

# %% [markdown]
# ## Exercise: Approximating a Function $f(x_1, x_2)$ using DNN
#
# You are given a dataset where a function $f(x_1, x_2)$ is sampled in the domain $[-1,1]^2$. The dataset consists of:
# - **Training data**: 2500 sampled points with corresponding function values (with noise).
# - **Testing data**: Function values computed on a $100 \times 100$ mesh grid.
#
# Your **task** is to:
# - **Load the dataset** from an h5py file.
# - **Build a suitable DNN model** with appropriate architecture, activation functions, and training settings (learning rate, batch size, epochs, etc.).
# - **Train the DNN model** and **save the trained weights**.
# - **Make predictions** using the trained model on the testing dataset and **evaluate the accuracy** using Mean Squared Error (MSE).
# - **Plot the predicted function** and ground truth using ```matplotlib```.
#
# **Instructions:**
# - The dataset is stored in an HDF5 (```regression_2d.h5```) file.
# - The training data is stored as:
#     - ```x_train```: shape (2500,2), contains $(x_1,x_2)$ pairs.
# 	- ```y_train```: shape (2500,1), contains the corresponding noisy function values.
# - The testing data is stored as:
# 	- ```x_test```: shape (10000,2), contains 100×100 mesh grid points.
# 	- ```y_test```: shape (10000,1), contains the corresponding function values.

# %%
import numpy as np
import h5py
import torch
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
np.random.seed(1234)
#
with h5py.File('regression_2d.h5', 'r') as f:
    print(f.keys())
    x_test = torch.tensor(np.array(f['x_test']))
    y_test = torch.tensor(np.array(f['y_test']))
    x_train = torch.tensor(np.array(f['x_train']))
    y_train = torch.tensor(np.array(f['y_train']))

# Plot the function
grid_x, grid_y = np.mgrid[-1:1:200j, -1:1:200j]  # High-resolution grid
grid_z = griddata((x_test[...,0], x_test[...,1]), y_test[...,0], (grid_x, grid_y), method='cubic')  # Cubic interpolation ['nearest', 'linear', 'cubic']
# 
plt.figure(figsize=(6,5))
plt.contourf(grid_x, grid_y, grid_z, levels=30, cmap="viridis")  # Filled contour plot
plt.scatter(x_train[...,0], x_train[...,1], color="red", marker="o", s=10, label="The training data points")  # Show original data points
plt.colorbar(label="Interpolated Values")
plt.xlabel(r"$x_1$")
plt.ylabel(r"$x_2$")
plt.title(r"The function $y=f(x_1, x_2)$")
plt.legend()
plt.show()
